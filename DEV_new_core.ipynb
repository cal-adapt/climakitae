# %% [markdown]
# # New Core

# %% [markdown]
# ### Set-Up
# Import the [climakitae](https://github.com/cal-adapt/climakitae) library and other dependencies.

# %%
from typing import Tuple
from typing import Any, Dict

import numpy as np
import pandas as pd
import xarray as xr
from tqdm.auto import tqdm  # Progress bar

import climakitae as ck

import warnings
warnings.filterwarnings("ignore")

# import functions needed for testing
from climakitae.core.constants import UNSET
from climakitae.core.paths import VARIABLE_DESCRIPTIONS_CSV_PATH

from climakitae.util.utils import read_csv_file, add_dummy_time_to_wl

# %% [markdown]
# ### Warming Level Processor: Add "add_dummy_time" as option to processor

# %%
cd = ck.ClimateData()
test_no = (
    cd.catalog("cadcat")
    .activity_id("WRF")
    .institution_id("UCLA")
    .table_id("day")
    .grid_label("d03")
    .variable("t2")
    .processes(
        {
            "warming_level": {
                "warming_levels": [1.5],
                #"add_dummy_time": True,
            }
        }
    )
    .get()
)

test_no_added = add_dummy_time_to_wl(test_no)
# Out:
# 2026-02-12 10:24:17 - climakitae.new_core.user_interface - INFO - Initializing ClimateData interface
# 2026-02-12 10:24:17 - climakitae.new_core.dataset_factory - INFO - DatasetFactory initialized with 3 validators and 11 processors
# 2026-02-12 10:24:17 - climakitae.new_core.user_interface - INFO - ClimateData initialization successful
# 2026-02-12 10:24:17 - climakitae.new_core.user_interface - INFO - ✅ Ready to query!
# 2026-02-12 10:24:17 - climakitae.new_core.user_interface - INFO - Catalog set to: cadcat
# 2026-02-12 10:24:17 - climakitae.new_core.user_interface - INFO - Activity ID set to: WRF
# 2026-02-12 10:24:17 - climakitae.new_core.user_interface - INFO - Institution ID set to: UCLA
# 2026-02-12 10:24:17 - climakitae.new_core.user_interface - INFO - Table ID set to: day
# 2026-02-12 10:24:17 - climakitae.new_core.user_interface - INFO - Grid label set to: d03
# 2026-02-12 10:24:17 - climakitae.new_core.user_interface - INFO - Variable set to: t2
# 2026-02-12 10:24:17 - climakitae.new_core.user_interface - INFO - Processes set: 1 operations configured
# 2026-02-12 10:24:17 - climakitae.new_core.user_interface - INFO - Starting data retrieval with query: {'catalog': 'cadcat', 'installation': UNSET, 'activity_id': 'WRF', 'institution_id': 'UCLA', 'source_id': UNSET, 'experiment_id': UNSET, 'table_id': 'day', 'grid_label': 'd03', 'variable_id': 't2', 'station_id': UNSET, 'network_id': UNSET, 'processes': {'warming_level': {'warming_levels': [1.5]}}}
# 2026-02-12 10:24:17 - climakitae.new_core.dataset_factory - INFO - Determined catalog key: cadcat
# 2026-02-12 10:24:18 - climakitae.new_core.dataset_factory - INFO - Adding 5 processing steps to dataset
# 2026-02-12 10:24:18 - climakitae.new_core.dataset_factory - INFO - Dataset created successfully
# 2026-02-12 10:24:18 - climakitae.new_core.user_interface - INFO - Dataset created successfully
# 2026-02-12 10:24:18 - climakitae.new_core.dataset - INFO - Executing dataset processing pipeline
# 2026-02-12 10:24:18 - climakitae.new_core.param_validation.abc_param_validation - INFO - Found 17 datasets matching your query.
# 2026-02-12 10:24:18 - climakitae.new_core.param_validation.abc_param_validation - INFO - Checking processes ...
# 2026-02-12 10:24:19 - climakitae.new_core.param_validation.cadcat_param_validator - INFO - Query validation result: True
# 2026-02-12 10:24:19 - climakitae.new_core.dataset - INFO - Parameter validation successful
# 2026-02-12 10:24:19 - climakitae.new_core.data_access.data_access - INFO - Querying cadcat catalog
# 2026-02-12 10:24:21 - climakitae.new_core.data_access.data_access - INFO - Retrieved 17 dataset(s) from catalog
# 2026-02-12 10:24:21 - climakitae.new_core.dataset - INFO - Data retrieved successfully
# 2026-02-12 10:24:21 - climakitae.new_core.dataset - INFO - Executing 5 processing steps
# 2026-02-12 10:24:21 - climakitae.new_core.processors.filter_unadjusted_models - WARNING -
#
# Your query selected models that do not have a-priori bias adjustment.
# These models have been removed from the returned query.
# To include them, please add the following processor to your query:
# ClimateData().processes('filter_unadjusted_models': 'no')
#
# 2026-02-12 10:24:21 - climakitae.new_core.processors.filter_unadjusted_models - INFO - Filtered out 6 unadjusted model entries
# 2026-02-12 10:24:24 - climakitae.new_core.processors.drop_leap_days - INFO - Dropped leap days from 11 data entries
# 2026-02-12 10:24:24 - climakitae.new_core.processors.processor_utils - INFO - Prepending historical data to SSP scenarios. This is the default concatenation strategy for retrieved data in climakitae. To change this behavior, set 'concat': 'sim' in your processes dictionary.
# 2026-02-12 10:24:25 - climakitae.new_core.processors.concatenate - INFO - Concatenated datasets along 'sim' dimension.
# 2026-02-12 10:24:25 - climakitae.new_core.processors.update_attributes - INFO - UpdateAttributes applied to result; added 6 attributes
# 2026-02-12 10:24:25 - climakitae.new_core.dataset - INFO - All processing steps completed successfully
# 2026-02-12 10:24:25 - climakitae.new_core.user_interface - INFO - ✅ Data retrieval successful!

# %%
cd = ck.ClimateData()
test_yes = (
    cd.catalog("cadcat")
    .activity_id("WRF")
    .institution_id("UCLA")
    .table_id("day")
    .grid_label("d03")
    .variable("t2")
    .processes(
        {
            "warming_level": {
                "warming_levels": [1.5],
                "add_dummy_time": True,
            }
        }
    )
    .get()
)
# Out:
# 2026-02-12 10:24:32 - climakitae.new_core.user_interface - INFO - Initializing ClimateData interface
# 2026-02-12 10:24:32 - climakitae.new_core.dataset_factory - INFO - DatasetFactory initialized with 3 validators and 11 processors
# 2026-02-12 10:24:32 - climakitae.new_core.user_interface - INFO - ClimateData initialization successful
# 2026-02-12 10:24:32 - climakitae.new_core.user_interface - INFO - ✅ Ready to query!
# 2026-02-12 10:24:32 - climakitae.new_core.user_interface - INFO - Catalog set to: cadcat
# 2026-02-12 10:24:32 - climakitae.new_core.user_interface - INFO - Activity ID set to: WRF
# 2026-02-12 10:24:32 - climakitae.new_core.user_interface - INFO - Institution ID set to: UCLA
# 2026-02-12 10:24:32 - climakitae.new_core.user_interface - INFO - Table ID set to: day
# 2026-02-12 10:24:32 - climakitae.new_core.user_interface - INFO - Grid label set to: d03
# 2026-02-12 10:24:32 - climakitae.new_core.user_interface - INFO - Variable set to: t2
# 2026-02-12 10:24:32 - climakitae.new_core.user_interface - INFO - Processes set: 1 operations configured
# 2026-02-12 10:24:32 - climakitae.new_core.user_interface - INFO - Starting data retrieval with query: {'catalog': 'cadcat', 'installation': UNSET, 'activity_id': 'WRF', 'institution_id': 'UCLA', 'source_id': UNSET, 'experiment_id': UNSET, 'table_id': 'day', 'grid_label': 'd03', 'variable_id': 't2', 'station_id': UNSET, 'network_id': UNSET, 'processes': {'warming_level': {'warming_levels': [1.5], 'add_dummy_time': True}}}
# 2026-02-12 10:24:32 - climakitae.new_core.dataset_factory - INFO - Determined catalog key: cadcat
# 2026-02-12 10:24:32 - climakitae.new_core.dataset_factory - INFO - Adding 5 processing steps to dataset
# 2026-02-12 10:24:32 - climakitae.new_core.dataset_factory - INFO - Dataset created successfully
# 2026-02-12 10:24:32 - climakitae.new_core.user_interface - INFO - Dataset created successfully
# 2026-02-12 10:24:32 - climakitae.new_core.dataset - INFO - Executing dataset processing pipeline
# 2026-02-12 10:24:32 - climakitae.new_core.param_validation.abc_param_validation - INFO - Found 17 datasets matching your query.
# 2026-02-12 10:24:32 - climakitae.new_core.param_validation.abc_param_validation - INFO - Checking processes ...
# 2026-02-12 10:24:33 - climakitae.new_core.param_validation.cadcat_param_validator - INFO - Query validation result: True
# 2026-02-12 10:24:33 - climakitae.new_core.dataset - INFO - Parameter validation successful
# 2026-02-12 10:24:33 - climakitae.new_core.data_access.data_access - INFO - Querying cadcat catalog
# 2026-02-12 10:24:35 - climakitae.new_core.data_access.data_access - INFO - Retrieved 17 dataset(s) from catalog
# 2026-02-12 10:24:35 - climakitae.new_core.dataset - INFO - Data retrieved successfully
# 2026-02-12 10:24:35 - climakitae.new_core.dataset - INFO - Executing 5 processing steps
# 2026-02-12 10:24:35 - climakitae.new_core.processors.filter_unadjusted_models - WARNING -
#
# Your query selected models that do not have a-priori bias adjustment.
# These models have been removed from the returned query.
# To include them, please add the following processor to your query:
# ClimateData().processes('filter_unadjusted_models': 'no')
#
# 2026-02-12 10:24:35 - climakitae.new_core.processors.filter_unadjusted_models - INFO - Filtered out 6 unadjusted model entries
# 2026-02-12 10:24:37 - climakitae.new_core.processors.drop_leap_days - INFO - Dropped leap days from 11 data entries
# 2026-02-12 10:24:37 - climakitae.new_core.processors.processor_utils - INFO - Prepending historical data to SSP scenarios. This is the default concatenation strategy for retrieved data in climakitae. To change this behavior, set 'concat': 'sim' in your processes dictionary.
# 2026-02-12 10:24:39 - climakitae.new_core.processors.concatenate - INFO - Concatenated datasets along 'sim' dimension.
# 2026-02-12 10:24:39 - climakitae.new_core.processors.update_attributes - INFO - UpdateAttributes applied to result; added 6 attributes
# 2026-02-12 10:24:39 - climakitae.new_core.dataset - INFO - All processing steps completed successfully
# 2026-02-12 10:24:39 - climakitae.new_core.user_interface - INFO - ✅ Data retrieval successful!

# %%
test_no
# Out:
# <xarray.Dataset> Size: 26GB
# Dimensions:            (sim: 5, warming_level: 1, time_delta: 10950, y: 492,
#                         x: 243)
# Coordinates:
#   * sim                (sim) object 40B 'WRF_UCLA_EC-Earth3_ssp370_day_d03_r1...
#   * warming_level      (warming_level) float64 8B 1.5
#     Lambert_Conformal  int32 4B 1
#     lakemask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     landmask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lat                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lon                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#   * x                  (x) float64 2kB -4.335e+06 -4.332e+06 ... -3.609e+06
#   * y                  (y) float64 4kB 4.549e+05 4.579e+05 ... 1.928e+06
#   * time_delta         (time_delta) int64 88kB -5475 -5474 -5473 ... 5473 5474
#     centered_year      (sim, warming_level) float64 40B 2.018e+03 ... 2.04e+03
# Data variables:
#     t2                 (sim, warming_level, time_delta, y, x) float32 26GB dask.array<chunksize=(1, 1, 608, 69, 33), meta=np.ndarray>
# Attributes: (12/120)
#     AERCU_FCT:                        1.0
#     AERCU_OPT:                        0
#     AUTO_LEVELS_OPT:                  2
#     BL_PBL_PHYSICS:                   1
#     BOTTOM-TOP_GRID_DIMENSION:        40
#     BOTTOM-TOP_PATCH_END_STAG:        40
#     ...                               ...
#     warming_level:                    {'warming_levels': [1.5]}
#     update_attributes:                Process 'update_attributes' applied to ...
#     filter_unadjusted_models:         yes
#     drop_leap_days:                   Leap days (February 29) have been remov...
#     concat:                           Process 'concat' applied to the data. T...
#     warming_level_simple:             Process 'warming_level_simple' applied ...

# %%
test_no_added
# Out:
# <xarray.Dataset> Size: 26GB
# Dimensions:            (sim: 5, warming_level: 1, time: 10950, y: 492, x: 243)
# Coordinates:
#   * sim                (sim) object 40B 'WRF_UCLA_EC-Earth3_ssp370_day_d03_r1...
#   * warming_level      (warming_level) float64 8B 1.5
#     Lambert_Conformal  int32 4B 1
#     lakemask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     landmask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lat                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lon                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#   * x                  (x) float64 2kB -4.335e+06 -4.332e+06 ... -3.609e+06
#   * y                  (y) float64 4kB 4.549e+05 4.579e+05 ... 1.928e+06
#     centered_year      (sim, warming_level) float64 40B 2.018e+03 ... 2.04e+03
#   * time               (time) datetime64[ns] 88kB 2000-01-01 ... 2029-12-31
# Data variables:
#     t2                 (sim, warming_level, time, y, x) float32 26GB dask.array<chunksize=(1, 1, 608, 69, 33), meta=np.ndarray>
# Attributes: (12/120)
#     AERCU_FCT:                        1.0
#     AERCU_OPT:                        0
#     AUTO_LEVELS_OPT:                  2
#     BL_PBL_PHYSICS:                   1
#     BOTTOM-TOP_GRID_DIMENSION:        40
#     BOTTOM-TOP_PATCH_END_STAG:        40
#     ...                               ...
#     warming_level:                    {'warming_levels': [1.5]}
#     update_attributes:                Process 'update_attributes' applied to ...
#     filter_unadjusted_models:         yes
#     drop_leap_days:                   Leap days (February 29) have been remov...
#     concat:                           Process 'concat' applied to the data. T...
#     warming_level_simple:             Process 'warming_level_simple' applied ...

# %%
test_yes
# Out:
# <xarray.Dataset> Size: 26GB
# Dimensions:            (sim: 5, warming_level: 1, time: 10950, y: 492, x: 243)
# Coordinates:
#   * sim                (sim) object 40B 'WRF_UCLA_EC-Earth3_ssp370_day_d03_r1...
#   * warming_level      (warming_level) float64 8B 1.5
#     Lambert_Conformal  int32 4B 1
#     lakemask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     landmask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lat                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lon                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#   * x                  (x) float64 2kB -4.335e+06 -4.332e+06 ... -3.609e+06
#   * y                  (y) float64 4kB 4.549e+05 4.579e+05 ... 1.928e+06
#   * time               (time) datetime64[ns] 88kB 2000-01-01 ... 2029-12-31
#     centered_year      (sim, warming_level) float64 40B 2.018e+03 ... 2.04e+03
# Data variables:
#     t2                 (sim, warming_level, time, y, x) float32 26GB dask.array<chunksize=(1, 1, 608, 69, 33), meta=np.ndarray>
# Attributes: (12/120)
#     AERCU_FCT:                        1.0
#     AERCU_OPT:                        0
#     AUTO_LEVELS_OPT:                  2
#     BL_PBL_PHYSICS:                   1
#     BOTTOM-TOP_GRID_DIMENSION:        40
#     BOTTOM-TOP_PATCH_END_STAG:        40
#     ...                               ...
#     warming_level:                    {'warming_levels': [1.5], 'add_dummy_ti...
#     update_attributes:                Process 'update_attributes' applied to ...
#     filter_unadjusted_models:         yes
#     drop_leap_days:                   Leap days (February 29) have been remov...
#     concat:                           Process 'concat' applied to the data. T...
#     warming_level_simple:             Process 'warming_level_simple' applied ...
